# %%
# %pip install pandas
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: pandas in /Users/belalelshenety/Documents/GitHub/DxHub/immunization-indicator-classifier/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/belalelshenety/Documents/GitHub/DxHub/immunization-indicator-classifier/.venv/lib/python3.12/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/belalelshenety/Documents/GitHub/DxHub/immunization-indicator-classifier/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/belalelshenety/Documents/GitHub/DxHub/immunization-indicator-classifier/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/belalelshenety/Documents/GitHub/DxHub/immunization-indicator-classifier/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/belalelshenety/Documents/GitHub/DxHub/immunization-indicator-classifier/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df_cdsi = pd.read_csv('CDSi.csv')
df_cdsi
# Out:
#     Observation Code  \
# 0                  4
# 1                 15
# 2                 16
# 3                 17
# 4                 27
# 5                 80
# 6                114
# 7                145
# 8                147
# 9                148
# 10               153
# 11               154
# 12               157
# 13               158
# 14               159
# 15               189
# 16               190
# 17               191
# 18               199
# 19               200
# 20               205
# 21               214
# 22               215
# 23               244
# 24               254
# 25               256
# 26               257
# 27               258
# 28               259
# 29               260
# 30               261
# 31               262
# 32               263
# 33               264
# 34               265
# 35               266
# 36               267
# 37               268
#
#                                                                                           Observation Title  \
# 0                                                         Recipient of a hematopoietic stem cell transplant
# 1                                                                                     Chronic liver disease
# 2                                                                                     Chronic heart disease
# 3                                                                                      Chronic lung disease
# 4                                                                                                    Asthma
# 5                                                                     Adverse reaction to vaccine component
# 6                                                                                   End stage renal disease
# 7                                                     B-lymphocyte [humoral] - Severe antibody deficiencies
# 8                                               T-lymphocyte [cell-mediated and humoral] - Complete defects
# 9                                                T-lymphocyte [cell-mediated and humoral] - Partial defects
# 10                          Phagocytic function - Leukocyte adhesion defect, and myeloperoxidase deficiency
# 11                                                                    HIV/AIDS - severely immunocompromised
# 12                                                                              Solid organ transplantation
# 13                                                                                Immunosuppressive therapy
# 14                                                                                        Radiation therapy
# 15                                                                        Active treatment for solid tumors
# 16                                                            Active treatment for hematologic malignancies
# 17                                                                            Receipt of CAR-T-cell therapy
# 18                                                                                Interstitial lung disease
# 19                                                                                          Cystic fibrosis
# 20                                                                                              Thalassemia
# 21                                                                    Chronic obstructive pulmonary disease
# 22                                                                                                Emphysema
# 23                                              Severe allergic reaction after previous dose of RSV vaccine
# 24                                                                           Chronic cardiovascular disease
# 25                                                  Diabetes mellitus complicated by chronic kidney disease
# 26                                                                                           Severe obesity
# 27                                                                            Chronic hematologic disorders
# 28                                                                                      Sickle cell disease
# 29  Neurologic or neuromuscular conditions causing impaired airway clearance or respiratory muscle weakness
# 30                                                                               Resident of a nursing home
# 31                                                                                                  Frailty
# 32                                                              Diabetes mellitus complicated by neuropathy
# 33                                                             Diabetes mellitus complicated by retinopathy
# 34                                                        Diabetes mellitus complicated by end-organ damage
# 35                                                                Diabetes requiring treatment with insulin
# 36                       Diabetes requiring treatment with sodium-glucose cotransporter-2 (SGLT2) inhibitor
# 37                                                                                    Islet Transplantation
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     SNOMED (Code)
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Hemopoietic stem cell transplant [procedure] (234336002);Transplantation of bone marrow [procedure] (23719005)
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Chronic liver disease [disorder] (328383001);Cirrhosis of liver [disorder] (19943007)
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Islet cell transplant [procedure] (128531006)

# %%
import pandas as pd

# Read the text file, treating each line as a row
df_cond = pd.read_fwf("Coreen424_Arica110_Lebsack687_af5d0128-dec1-e36d-fea7-ced3f7c9652c.txt", header=None, names=["Text"])
df_cond
# Out:
#                                                                                                  Text
# Coreen424 Arica110 Lebsack687                                                               NaN   NaN
# =============================                                                               NaN   NaN
# Race:                White                                                                  NaN   NaN
# Ethnicity:           Non-Hispanic                                                           NaN   NaN
# Gender:              F                                                                      NaN   NaN
# ...                                                                                               ...
# 2017-09-14 : Digital Radiography, Structure of region of internal part of mouth (body struc ure)  NaN
# 2016-01-21 : Digital Radiography, Structure of region of internal part of mouth (body struc ure)  NaN
# 2015-08-27 : Digital Radiography, Structure of region of internal part of mouth (body struc ure)  NaN
# 1994-11-03 : Digital Radiography, Structure of region of internal part of mouth (body struc ure)  NaN
# --------------------------------------------------------------------------------            NaN   NaN
#
# [6865 rows x 1 columns]

# %%
import pandas as pd

# Read the text file with each line as a separate row in one column
df_cond = pd.read_csv("example_ehr.txt", header=None)
# df = pd.read_csv("your_file.txt", sep="\n", header=None, names=["Text"], dtype=str, engine="python", on_bad_lines="skip")

# Display the first few rows
df_cond
# Out:
#                                                                                  0
# 0                                                    Coreen424 Arica110 Lebsack687
# 1                                                    =============================
# 2                                                       Race:                White
# 3                                                Ethnicity:           Non-Hispanic
# 4                                                           Gender:              F
# ..                                                                             ...
# 391                    1981-11-26 -            : Essential hypertension (disorder)
# 392              1977-12-15 -            : Body mass index 30+ - obesity (finding)
# 393    1964-07-15 -            : Past pregnancy history of miscarriage (situation)
# 394                         1962-04-22 -            : Chronic sinusitis (disorder)
# 395                  1950-01-19 -            : Received higher education (finding)
#
# [396 rows x 1 columns]

# %%
df_cond.iloc[15]
# Out:
# Text      2024-10-24[CURRENT] : Acetaminophen 300 MG / Hydrocodone Bitartrate 5 MG Oral Tablet
# Name: 15, dtype: object

# %%
pd.set_option('display.max_colwidth', None)
df_cond.iloc[15]
# Out:
# Text      2024-10-24[CURRENT] : Acetaminophen 300 MG / Hydrocodone Bitartrate 5 MG Oral Tablet
# Name: 15, dtype: object

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Define model names
model = "neuml/pubmedbert-base-embeddings"

# Load tokenizers and models
tokenizer = AutoTokenizer.from_pretrained(model, token = "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") 
model = AutoModel.from_pretrained(model)

# %%
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def get_embedding(row):
    """Convert entire row to text and generate embeddings"""
    text = " ".join(row.astype(str))  # Convert row to a string
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1)[0]

# %%
len(get_embedding(df_cond.iloc[0]))
# Out:
# 768

# %%
import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Example usage with your existing DataFrames
# df_cdsi['Embedding'] = df_cdsi.apply(get_embedding, axis=1)
df_cond['Embedding'] = df_cond.apply(get_embedding, axis=1)

# %%
len(df_cdsi['Embedding'][0])
# Out:
# 768

# %%
def compute_similarities(df1, df2, threshold=0.5):
    """Find and print the most similar row in df2 for each row in df1, only if similarity > threshold."""
    for idx, row in df1.iterrows():
        row_embedding = np.array([row['Embedding']])  # Embed the row
        all_embeddings = np.vstack(df2['Embedding'].values)  # Stack all embeddings from df2

        similarities = cosine_similarity(row_embedding, all_embeddings)[0]  # Compute cosine similarity
        df2['Similarity'] = similarities  # Attach similarities to df2

        top_match = df2.sort_values(by='Similarity', ascending=False).iloc[0]  # Find best match
        best_similarity = top_match['Similarity']

        # Only print if the similarity exceeds the threshold
        if best_similarity >= threshold:
            print(f"Row {idx} from df1: {row.drop('Embedding', errors='ignore').to_dict()}")
            print(f"Best Match in df2: {top_match.drop(['Embedding', 'Similarity'], errors='ignore').to_dict()}")
            print(f"Similarity Score: {best_similarity:.4f}")
            print("-" * 80)

# Example: Compute similarities with a threshold of 0.7
compute_similarities(df_cdsi, df_cond, threshold=0.6)
# Out:
# Row 2 from df1: {'Observation Code': 16, 'Observation Title': 'Chronic heart disease', 'SNOMED (Code)': 'Chronic heart disease [disorder] (128238001);Congestive heart failure [disorder] (42343007);Myocardial disease [disorder] (57809008);Cyanotic congenital heart disease [disorder] (12770006);Coronary arteriosclerosis [disorder] (53741008);Mitral valve stenosis [disorder] (79619009);Cardiac arrhythmia [disorder] (698247007)'}
# Best Match in df2: {0: '  1986-12-25 -            : Ischemic heart disease (disorder)'}
# Similarity Score: 0.6916
# --------------------------------------------------------------------------------
# Row 6 from df1: {'Observation Code': 114, 'Observation Title': 'End stage renal disease', 'SNOMED (Code)': 'End stage renal disease [disorder] (46177005);Dependence on hemodialysis [finding] (443143006);Continuous renal replacement therapy [procedure] (714749008)'}
# Best Match in df2: {0: '  1986-12-25 -            : Chronic kidney disease stage 2 (disorder)'}
# Similarity Score: 0.6203
# --------------------------------------------------------------------------------
# Row 24 from df1: {'Observation Code': 254, 'Observation Title': 'Chronic cardiovascular disease', 'SNOMED (Code)': 'Chronic disease of cardiovascular system [disorder] (128292002);Peripheral vascular disease [disorder] (400047006);Limb ischemia [disorder] (21631000119105);Intermittent claudication [finding] (63491006);arterial thrombosis [disorder] (65198009);Chronic vascular insufficiency of intestine [disorder] (111354009);Pulmonary hypertension [disorder] (70995007);Pulmonary embolism [disorder] (59282003);Portal vein thrombosis [disorder] (17920008);Aortic aneurysm [disorder] (67362008);Type II dissection of thoracic aorta [disorder] (233996000);Dissection of proximal aorta [disorder] (301899003);Dissection of distal aorta [disorder] (233997009);Dissection of aortic arch [disorder] (27631000146108);Medionecrosis of aorta [disorder] (45894003);Dissection of infrarenal aorta [disorder] (1303726005)'}
# Best Match in df2: {0: '  1986-12-25 -            : Ischemic heart disease (disorder)'}
# Similarity Score: 0.6552
# --------------------------------------------------------------------------------
# Row 25 from df1: {'Observation Code': 256, 'Observation Title': 'Diabetes mellitus complicated by chronic kidney disease', 'SNOMED (Code)': 'Disorder of kidney due to diabetes mellitus [disorder] (127013003)'}
# Best Match in df2: {0: '  1986-12-25 -            : Disorder of kidney due to diabetes mellitus (disorder)'}
# Similarity Score: 0.7045
# --------------------------------------------------------------------------------
# Row 26 from df1: {'Observation Code': 257, 'Observation Title': 'Severe obesity', 'SNOMED (Code)': 'Severe obesity [disorder] (83911000119104);Body mass index 40+ - severely obese [finding] (408512008)'}
# Best Match in df2: {0: '  1977-12-15 -            : Body mass index 30+ - obesity (finding)'}
# Similarity Score: 0.6715
# --------------------------------------------------------------------------------
# Row 35 from df1: {'Observation Code': 266, 'Observation Title': 'Diabetes requiring treatment with insulin', 'SNOMED (Code)': 'Diabetic on insulin [finding] (170747006) '}
# Best Match in df2: {0: '  1986-12-25 -            : Microalbuminuria due to type 2 diabetes mellitus (disorder)'}
# Similarity Score: 0.6013
# --------------------------------------------------------------------------------
