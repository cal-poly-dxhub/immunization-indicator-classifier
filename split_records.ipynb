# %%
import pandas as pd
import re
import numpy as np


class Form:
    def __init__(self, file_path):
        self.file_path = file_path
        pass

    def process_conditions_section(self):
        with open(self.file_path, "r") as file:
            text = file.read()

        # Extract the CONDITIONS section
        conditions_section = re.search(
            r"CONDITIONS:\n(.*?)\n-{80}", text, re.DOTALL
        ).group(1)

        # Split the section into individual condition entries
        condition_entries = conditions_section.strip().split("\n")

        # Initialize lists to store the parsed data
        start_dates = []
        end_dates = []
        descriptions = []

        # Parse each condition entry
        for entry in condition_entries:
            match = re.match(
                r"\s*(\d{4}-\d{2}-\d{2}) -\s*(\d{4}-\d{2}-\d{2}|)\s*:\s*(.*)", entry
            )
            if match:
                start_date = match.group(1)
                end_date = match.group(2) if match.group(2) else None
                description = match.group(3)

                start_dates.append(start_date)
                end_dates.append(end_date)
                descriptions.append(description)

        # Create a DataFrame from the parsed data
        df = pd.DataFrame(
            {"start": start_dates, "end": end_dates, "description": descriptions}
        )

        return df

    def process_observations_section(self):
        # Read the text file
        with open(self.file_path, "r") as file:
            text = file.read()

        # Extract the observations section
        observations_section = re.search(
            r"OBSERVATIONS:(.*?)(?=IMMUNIZATIONS:)", text, re.DOTALL
        ).group(1)

        # Split the observations into individual entries
        observations = re.findall(
            r"(\d{4}-\d{2}-\d{2}.*?)(?=\d{4}-\d{2}-\d{2}|$)",
            observations_section,
            re.DOTALL,
        )

        # Create a DataFrame with columns date and content
        data = []
        for observation in observations:
            date = re.search(r"\d{4}-\d{2}-\d{2}", observation).group(0)
            content = observation[len(date) :].strip()
            if content.startswith(":"):
                content = content[1:].strip()
            data.append([date, content])

        df = pd.DataFrame(data, columns=["date", "content"])

        return df

# %%
form = Form("shortened_example.txt")

# %%
obs_df = form.process_observations_section()
obs_df.head(30)
# Out:
#           date                                            content
# 0   2014-04-24  Cause of Death [US Standard Certificate of Dea...
# 1   2014-03-27  Patient Health Questionnaire 2 item (PHQ-2) to...
# 2   2014-03-27  Total score [HARK]                       0.0 {...
# 3   2014-03-27  Fall risk level [Morse Fall Scale]       High ...
# 4   2014-03-27  Fall risk total [Morse Fall Scale]       101.0...
# 5   2014-03-27  Generalized anxiety disorder 7 item (GAD-7) to...
# 6   2014-03-27  Protocol for Responding to and Assessing Patie...
# 7   2014-03-27  Tobacco smoking status                   Never...
# 8   2014-03-27  Carbon dioxide, total [Moles/volume] in Blood ...
# 9   2014-03-27  Chloride [Moles/volume] in Blood         109.7...
# 10  2014-03-27  Potassium [Moles/volume] in Blood        4.8 m...
# 11  2014-03-27  Sodium [Moles/volume] in Blood           141.9...
# 12  2014-03-27  Calcium [Mass/volume] in Blood           9.0 m...
# 13  2014-03-27  Creatinine [Mass/volume] in Blood        0.5 m...
# 14  2014-03-27  Urea nitrogen [Mass/volume] in Blood     18.7 ...
# 15  2014-03-27  Glucose [Mass/volume] in Blood           73.6 ...
# 16  2014-03-27  Respiratory rate                         16.0 ...
# 17  2014-03-27  Heart rate                               72.0 ...
# 18  2014-03-27  Blood pressure panel with all children optiona...
# 19  2014-03-27  Body mass index (BMI) [Ratio]            27.6 ...
# 20  2014-03-27   Body Weight                              69.9 kg
# 21  2014-03-27  Pain severity - 0-10 verbal numeric rating [Sc...
# 22  2014-03-27  Body Height                              159.2 cm
# 23  2014-03-27     Hemoglobin A1c/Hemoglobin.total in Blood 6.4 %
# 24  2013-10-03  Total score [MMSE]                       4.7 {...
# 25  2013-05-23  Patient Health Questionnaire 2 item (PHQ-2) to...
# 26  2013-05-23  Fall risk level [Morse Fall Scale]       Low R...
# 27  2013-05-23  Fall risk total [Morse Fall Scale]       12.0 {#}
# 28  2013-05-23  Protocol for Responding to and Assessing Patie...
# 29  2011-02-10  Protocol for Responding to and Assessing Patie...

# %%
cond_df = form.process_conditions_section()
cond_df.head(30)
# Out:
#          start         end                                       description
# 0   2014-04-03        None                        Viral sinusitis (disorder)
# 1   2014-03-27        None                    Part-time employment (finding)
# 2   2014-03-27  2014-03-27                 Medication review due (situation)
# 3   2013-05-23        None                                  Stress (finding)
# 4   2013-05-23  2014-03-27                      Not in labor force (finding)
# 5   2013-05-23  2013-05-23                 Medication review due (situation)
# 6   2012-05-17  2012-05-31                             Gingivitis (disorder)
# 7   2012-05-17  2013-05-23  Reports of violence in the environment (finding)
# 8   2012-05-17  2012-05-17                 Medication review due (situation)
# 9   2011-06-23  2011-07-06                       Acute bronchitis (disorder)
# 10  2011-05-12  2011-05-26                             Gingivitis (disorder)
# 11  2011-05-12  2012-05-17                                  Stress (finding)
# 12  2011-05-12  2011-06-09                  Limited social contact (finding)
# 13  2011-05-12  2013-05-23                    Full-time employment (finding)
# 14  2011-03-10  2011-04-02                        Viral sinusitis (disorder)
# 15  2011-02-24  2011-05-12                      Not in labor force (finding)
# 16  2011-02-10  2011-03-03                             Gingivitis (disorder)
# 17  2010-05-06  2011-06-16                 Medication review due (situation)
# 18  2009-04-30  2009-04-30                 Medication review due (situation)
# 19  2009-04-30        None                    Alzheimer's disease (disorder)
# 20  2008-08-21  2008-09-13              Acute bacterial sinusitis (disorder)

# %%
cond_df[cond_df["end"].isnull()]
# Out:
#          start   end                     description
# 0   2014-04-03  None      Viral sinusitis (disorder)
# 1   2014-03-27  None  Part-time employment (finding)
# 3   2013-05-23  None                Stress (finding)
# 19  2009-04-30  None  Alzheimer's disease (disorder)

# %%
obs_df.iloc[29].content
# Out:
# "Protocol for Responding to and Assessing Patients' Assets, Risks, and Experiences [PRAPARE]\n           - Within the last year, have you been afraid of your partner or ex-partner? No \n           - Do you feel physically and emotionally safe where you currently live? Yes \n           - Are you a refugee?                       No \n           - In the past year, have you spent more than 2 nights in a row in a jail, prison, detention center, or juvenile correctional facility? No \n           - Stress level                             Not at all \n           - How often do you see or talk to people that you care about and feel close to (For example: talking to friends on the phone, visiting friends or family, going to church or club meetings)? 3 to 5 times a week \n           - Has lack of transportation kept you from medical appointments, meetings, work, or from getting things needed for daily living No \n           - In the past year, have you or any family members you live with been unable to get any of the following when it was really needed? I choose not to answer this question \n           - What was your best estimate of the total income of all family members from all sources, before taxes, in last year? 8213 /a\n           - Primary insurance                        I choose not to answer this question \n           - Employment status - current              Full-time work \n           - Highest level of education               More than high school \n           - Address                                  372 Bode Lodge \n           - Are you worried about losing your housing? Yes \n           - Housing status                           I have housing \n           - How many people are living or staying at this address? 6.0 {#}\n           - Preferred language                       English \n           - Have you been discharged from the armed forces of the United States? No \n           - At any point in the past 2 years, has season or migrant farm work been your or your family's main source of income? No \n           - Race                                     White \n           - Do you consider yourself Hispanic/Latino? No \n--------------------------------------------------------------------------------"

# %%
CONDITIONS_PATH = "category_generator/data/CDSi ScheduleSupportingData- Coded Observations-508_v4.60_withRSV.csv"
codes_df = pd.read_csv(CONDITIONS_PATH)
codes_df.head()
# Out:
#    Observation Code                                  Observation Title  \
# 0               1.0                           Patient seeks protection
# 1               2.0                    Undergoing elective splenectomy
# 2               3.0                                  Immunocompromised
# 3               4.0  Recipient of a hematopoietic stem cell transplant
# 4               5.0                        Hepatitis C virus infection
#
#                          Indication Text Description  \
# 0          Administer to persons seeking protection.
# 1  Administer to persons who are undergoing elect...
# 2                                                NaN
# 3  Administer to recipients of a hematopoietic st...
# 4  Administer to persons with a hepatitis C virus...
#
#                    Contraindication Text Description  \
# 0                                                NaN
# 1                                                NaN
# 2  Do not vaccinate if the patient is immunocompr...
# 3                                                NaN
# 4                                                NaN
#
#                                      Clarifying Text  \
# 0                                                NaN
# 1  Vaccination 14 or more days before splenectomy...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        SNOMED (Code) CVX (Code)  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2              Patient Immunocompromised (370388006)        NaN
# 3  Hemopoietic stem cell transplant [procedure] (...        NaN
# 4       Viral hepatitis type C [disorder] (50711007)        NaN
#
#                               PHIN VS (Code) Relevance to RSV for 60-74y?  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2  Immunodeficiency due to any cause (VXC27)                          NaN
# 3                                        NaN                   Indication
# 4                                        NaN                          NaN
#
#   CDSi Observation Notes relevant to RSV for 60-74y  ...  Unnamed: 16  \
# 0                                               NaN  ...          NaN
# 1                                               NaN  ...          NaN
# 2                                               NaN  ...          NaN
# 3                                               NaN  ...          NaN
# 4                                               NaN  ...          NaN
#
#    Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
codes_df.isna().sum()
# Out:
# Observation Code                                     732
# Observation Title                                    732
# Indication Text Description                          834
# Contraindication Text Description                    883
# Clarifying Text                                      941
# SNOMED (Code)                                        852
# CVX (Code)                                           968
# PHIN VS (Code)                                       967
# Relevance to RSV for 60-74y?                         961
# CDSi Observation Notes relevant to RSV for 60-74y    989
# Unnamed: 10                                          999
# Unnamed: 11                                          999
# Unnamed: 12                                          999
# Unnamed: 13                                          999
# Unnamed: 14                                          999
# Unnamed: 15                                          999
# Unnamed: 16                                          999
# Unnamed: 17                                          999
# Unnamed: 18                                          999
# Unnamed: 19                                          999
# Unnamed: 20                                          999
# Unnamed: 21                                          999
# Unnamed: 22                                          999
# Unnamed: 23                                          999
# Unnamed: 24                                          999
# Unnamed: 25                                          999
# dtype: int64

# %%
cols_to_drop = [f"Unnamed: {i}" for i in range(10, 25 + 1)]
codes_df.drop(columns=cols_to_drop, inplace=True)

# %%
codes_df
# Out:
#      Observation Code                                  Observation Title  \
# 0                 1.0                           Patient seeks protection
# 1                 2.0                    Undergoing elective splenectomy
# 2                 3.0                                  Immunocompromised
# 3                 4.0  Recipient of a hematopoietic stem cell transplant
# 4                 5.0                        Hepatitis C virus infection
# ..                ...                                                ...
# 994               NaN                                                NaN
# 995               NaN                                                NaN
# 996               NaN                                                NaN
# 997               NaN                                                NaN
# 998               NaN                                                NaN
#
#                            Indication Text Description  \
# 0            Administer to persons seeking protection.
# 1    Administer to persons who are undergoing elect...
# 2                                                  NaN
# 3    Administer to recipients of a hematopoietic st...
# 4    Administer to persons with a hepatitis C virus...
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
#
#                      Contraindication Text Description  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Do not vaccinate if the patient is immunocompr...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
#
#                                        Clarifying Text  \
# 0                                                  NaN
# 1    Vaccination 14 or more days before splenectomy...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
#
#                                          SNOMED (Code) CVX (Code)  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                Patient Immunocompromised (370388006)        NaN
# 3    Hemopoietic stem cell transplant [procedure] (...        NaN
# 4         Viral hepatitis type C [disorder] (50711007)        NaN
# ..                                                 ...        ...
# 994                                                NaN        NaN
# 995                                                NaN        NaN
# 996                                                NaN        NaN
# 997                                                NaN        NaN
# 998                                                NaN        NaN
#
#                                 PHIN VS (Code) Relevance to RSV for 60-74y?  \
# 0                                          NaN                          NaN
# 1                                          NaN                          NaN
# 2    Immunodeficiency due to any cause (VXC27)                          NaN
# 3                                          NaN                   Indication
# 4                                          NaN                          NaN
# ..                                         ...                          ...
# 994                                        NaN                          NaN
# 995                                        NaN                          NaN
# 996                                        NaN                          NaN
# 997                                        NaN                          NaN
# 998                                        NaN                          NaN
#
#     CDSi Observation Notes relevant to RSV for 60-74y
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 994                                               NaN
# 995                                               NaN
# 996                                               NaN
# 997                                               NaN
# 998                                               NaN
#
# [999 rows x 10 columns]

# %%
# find the first row that's all NaN
first_nan_row = codes_df.isna().all(axis=1).idxmax()
conditions_df = codes_df.iloc[:first_nan_row]

# %%
codes_df
# Out:
#      Observation Code                                  Observation Title  \
# 0                 1.0                           Patient seeks protection
# 1                 2.0                    Undergoing elective splenectomy
# 2                 3.0                                  Immunocompromised
# 3                 4.0  Recipient of a hematopoietic stem cell transplant
# 4                 5.0                        Hepatitis C virus infection
# ..                ...                                                ...
# 994               NaN                                                NaN
# 995               NaN                                                NaN
# 996               NaN                                                NaN
# 997               NaN                                                NaN
# 998               NaN                                                NaN
#
#                            Indication Text Description  \
# 0            Administer to persons seeking protection.
# 1    Administer to persons who are undergoing elect...
# 2                                                  NaN
# 3    Administer to recipients of a hematopoietic st...
# 4    Administer to persons with a hepatitis C virus...
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
#
#                      Contraindication Text Description  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Do not vaccinate if the patient is immunocompr...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
#
#                                        Clarifying Text  \
# 0                                                  NaN
# 1    Vaccination 14 or more days before splenectomy...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
#
#                                          SNOMED (Code) CVX (Code)  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                Patient Immunocompromised (370388006)        NaN
# 3    Hemopoietic stem cell transplant [procedure] (...        NaN
# 4         Viral hepatitis type C [disorder] (50711007)        NaN
# ..                                                 ...        ...
# 994                                                NaN        NaN
# 995                                                NaN        NaN
# 996                                                NaN        NaN
# 997                                                NaN        NaN
# 998                                                NaN        NaN
#
#                                 PHIN VS (Code) Relevance to RSV for 60-74y?  \
# 0                                          NaN                          NaN
# 1                                          NaN                          NaN
# 2    Immunodeficiency due to any cause (VXC27)                          NaN
# 3                                          NaN                   Indication
# 4                                          NaN                          NaN
# ..                                         ...                          ...
# 994                                        NaN                          NaN
# 995                                        NaN                          NaN
# 996                                        NaN                          NaN
# 997                                        NaN                          NaN
# 998                                        NaN                          NaN
#
#     CDSi Observation Notes relevant to RSV for 60-74y
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 994                                               NaN
# 995                                               NaN
# 996                                               NaN
# 997                                               NaN
# 998                                               NaN
#
# [999 rows x 10 columns]

# %%
print(codes_df.iloc[4]["Indication Text Description"])
print(codes_df.iloc[4])
# Out:
# Administer to persons with a hepatitis C virus infection.
# Observation Code                                                                                   5.0
# Observation Title                                                          Hepatitis C virus infection
# Indication Text Description                          Administer to persons with a hepatitis C virus...
# Contraindication Text Description                                                                  NaN
# Clarifying Text                                                                                    NaN
# SNOMED (Code)                                             Viral hepatitis type C [disorder] (50711007)
# CVX (Code)                                                                                         NaN
# PHIN VS (Code)                                                                                     NaN
# Relevance to RSV for 60-74y?                                                                       NaN
# CDSi Observation Notes relevant to RSV for 60-74y                                                  NaN
# Name: 4, dtype: object

# %%
codes_df.isna().sum()
# Out:
# Observation Code                                     732
# Observation Title                                    732
# Indication Text Description                          834
# Contraindication Text Description                    883
# Clarifying Text                                      941
# SNOMED (Code)                                        852
# CVX (Code)                                           968
# PHIN VS (Code)                                       967
# Relevance to RSV for 60-74y?                         961
# CDSi Observation Notes relevant to RSV for 60-74y    989
# dtype: int64
